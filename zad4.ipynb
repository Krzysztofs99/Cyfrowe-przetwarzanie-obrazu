# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import scipy.signal

# %%
im = np.array(Image.open('zad4_1.jpg'))/255.0

plt.figure(figsize = (6, 6))
plt.imshow(im, cmap='gray')

# %%
mask = np.ones((5,5))
mask

im_a = scipy.signal.convolve2d(im, mask, 'same')

plt.figure(figsize = (12, 6))
plt.imshow(im_a, cmap='gray')

# %%
im2 = np.array(Image.open('zad4_2.jpg'))/255.0
plt.figure(figsize = (12, 6))
plt.imshow(im2, cmap='gray')

# %%
mask = np.array([[ 0, -1,  0],
                 [-1,  4, -1],
                 [ 0, -1,  0]])

print(f'mask={mask}')

#Filtracja obrazu
im_f = scipy.signal.convolve2d(im_blur, mask, 'same')
im_sharp2 = im_blur + 50*im_f

plt.figure(figsize = (12, 6))

plt.subplot(1,2,1)
plt.imshow(im_blur, cmap='gray')
plt.clim(0, 0.7)
plt.colorbar()

plt.subplot(1,2,2)
plt.imshow(im_sharp2, cmap='gray')
plt.clim(0, 0.7)
plt.colorbar()
# Out:
# mask=[[ 0 -1  0]
#  [-1  4 -1]
#  [ 0 -1  0]]
